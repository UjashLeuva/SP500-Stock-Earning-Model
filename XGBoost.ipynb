# %%
import datetime
import seaborn as sns
import time

import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA

import math


from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score



# Other packages
import numpy as np
import pandas as pd
import re
import scipy as sp
import xgboost as xgb
import matplotlib.pyplot as plt
from numpy import concatenate
from pandas import DataFrame, Series, read_csv, scatter_matrix

import warnings
warnings.filterwarnings("ignore")

# %%
SP500_TechIndicator = read_csv('SP500_tech_Indicator.csv')
SP500_TechIndicator = SP500_TechIndicator.drop(['Unnamed: 0'], axis=1)
SP500_TechIndicator.shape
SP500_TechIndicator
# Out:
#             Date  Activision_Blizzard_Open  Activision_Blizzard_Close  \
# 0     2013-12-31                    17.800                     17.830
# 1     2014-01-02                    17.910                     18.070
# 2     2014-01-03                    17.800                     18.290
# 3     2014-01-06                    18.380                     18.080
# 4     2014-01-07                    18.200                     18.315
# 5     2014-01-08                    18.320                     18.340
# 6     2014-01-09                    18.410                     18.300
# 7     2014-01-10                    18.380                     18.180
# 8     2014-01-13                    18.020                     17.870
# 9     2014-01-14                    17.780                     17.490
# 10    2014-01-15                    17.560                     17.390
# 11    2014-01-16                    17.370                     17.330
# ...

# %%
#Activision_Blizzard

Predictors = pd.DataFrame({"sma2":CNHI["data"].Open.rolling(window=2).mean()})

Predictors["SMA_increment_Activision_Blizzard"] = Predictors.SMA_Activision_Blizzard.diff()  
 
#Predictors["sma2_1_increment"] = Predictors.sma2_1.diff()  
 
Predictors["upper_band_Activision_Blizzard"] = SP500_TechIndicator["Activision_Blizzard"].Volume.diff()
 
Predictors["Activision_Blizzard_Open_1"] = SP500_TechIndicator["Activision_Blizzard_Open"].shift(1)
 
Predictors["Activision_Blizzard_open_incr"] = SP500_TechIndicator["Activision_Blizzard_Open"] - SP500_TechIndicator["Activision_Blizzard_Open"].shift(1)
 
Predictors["Activision_Blizzard_Open"] = SP500_TechIndicator["Activision_Blizzard_Open"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7e9b4ee57998> in <module>
#       1 #Activision_Blizzard
#       2
# ----> 3 Predictors["SMA_increment_Activision_Blizzard"] = Predictors.SMA_Activision_Blizzard.diff()
#       4
#       5 #Predictors["sma2_1_increment"] = Predictors.sma2_1.diff()
#
# NameError: name 'Predictors' is not defined
